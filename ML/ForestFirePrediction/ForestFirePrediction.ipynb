# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/HarithaNagamalla/Downloads/Forest_fire.csv')

# %%
df
# Out:
#          Area  Oxygen  Temperature  Humidity  Fire Occurrence
# 0    Jharkand      40           45        20                1
# 1   Bangalore      50           30        10                1
# 2     Ecuador      10           20        70                0
# 3           a      60           45        70                1
# 4   Bangalore      30           48        10                1
# 5           c      50           15        30                0
# 6          de       5           35        35                0
# 7         asd       5           20        70                0
# 8     Ecuador      60           32        19                1
# 9           r      30           50        45                1
# 10          t      40           55        80                1
# 11          y      30           39       100                0
# 12   Jharkand      10           12        12                0
# 13  Bangalore      20           23        23                0
# ...

# %%
df.isnull().sum()
# Out:
# Area               10
# Oxygen              0
# Temperature         0
# Humidity            0
# Fire Occurrence     0
# dtype: int64

# %%
df= df.fillna(method='ffill')
# Out:
# C:\Users\HarithaNagamalla\AppData\Local\Temp\ipykernel_8108\2724439788.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df= df.fillna(method='ffill')

# %%
df
# Out:
#          Area  Oxygen  Temperature  Humidity  Fire Occurrence
# 0    Jharkand      40           45        20                1
# 1   Bangalore      50           30        10                1
# 2     Ecuador      10           20        70                0
# 3           a      60           45        70                1
# 4   Bangalore      30           48        10                1
# 5           c      50           15        30                0
# 6          de       5           35        35                0
# 7         asd       5           20        70                0
# 8     Ecuador      60           32        19                1
# 9           r      30           50        45                1
# 10          t      40           55        80                1
# 11          y      30           39       100                0
# 12   Jharkand      10           12        12                0
# 13  Bangalore      20           23        23                0
# ...

# %%
# from sklearn.preprocessing import LabelEncoder

# encoder = LabelEncoder()
# df['Area_Encoded'] = encoder.fit_transform(df['Area'])

# #

# %%
# df = df.astype(int)

# %%
# df

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import joblib

# %%
x = df[['Temperature', 'Oxygen', 'Humidity']]
y = df['Fire Occurrence']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
rf = RandomForestClassifier(n_estimators = 100, random_state=42)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[6 0]
#  [0 2]]

# %%
joblib.dump(rf, 'random_forest_model.pkl')
print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
loaded_model = joblib.load('random_forest_model.pkl')
print(f'Type of loaded model: {type(loaded_model)}')
# Out:
# Type of loaded model: <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
sample_data = x_test.iloc[0].values.reshape(1, -1)
prediction =loaded_model.predict(sample_data)
print(f"Prediction: {prediction}")
# Out:
# Prediction: [0]
# C:\Users\HarithaNagamalla\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# joblib.dump(encoder, 'label_encoder.pkl')

# %%
x_test
# Out:
#     Temperature  Oxygen  Humidity
# 33           30      20         5
# 36           10      10        60
# 4            48      30        10
# 13           23      20        23
# 30           43      42        20
# 26           12      21        44
# 6            35       5        35
# 27           20      11        59

# %%
sample_data
# Out:
# array([[30, 20,  5]], dtype=int64)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0

# %%
pip install scikit-learn==1.5.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn joblib pandas  # Install required libraries
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#'

# %%
pip install scikit-learn==1.5.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0
